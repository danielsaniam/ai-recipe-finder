# %% [markdown]
# <a href="https://colab.research.google.com/github/danielsaniam/ai-recipe-finder/blob/main/IamCooking_Pinecone_query.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U sentence-transformers
# !pip install pinecone-client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 941.6 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.7 MB/s eta 0:00:00
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=eeb47fd0b0b3d22576bf38c4c197323e5dbc1400bd3aab76b7daafd7dc85137d
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.4/179.4 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 6.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import pinecone
from getpass import getpass

# %%
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
# Out:
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
pincone_api = getpass('Enter the secret value: ')
# Out:
# Enter the secret value: ··········

# %%
pinecone.init(api_key=pincone_api, environment="gcp-starter")

# %%
index_name = 'recipes-embeddings'
index = pinecone.Index(index_name)

# %%
query = 'receta pata el inicio del dia'
query_vector = model.encode(query).tolist()

responses = index.query(
  vector=query_vector,
  top_k=3,
  include_metadata=True,
  filter ={}
)

# %%
responses
# Out:
# {'matches': [{'id': '27006',
#               'metadata': {'ingredients': '2 kilos de patatas 6 almendras 1 '
#                                           'rebanada de pan 2 dientes de ajo 3 '
#                                           'cucharadas de aceite 1 papel de '
#                                           'azafrán (una carterita de '
#                                           'colorante) Perejil Sal Pimienta',
#                            'steps': '1 Se quita la piel a las patatas, se '
#                                     'lavan y después se parten en trozos '
#                                     'regulares y se colocan en una cacerola. '
#                                     'En una sartén pequeña se echa el aceite, '
#                                     'se calienta y se añaden los dientes de '
#                                     'ajo, las almendras, la rebanada de pan y '
#                                     'el perejil. 2 Bien dorado todo, se saca y '
# ...
